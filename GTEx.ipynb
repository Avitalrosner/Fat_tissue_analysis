# %%
## Finding MARKER GENES from GTEx

# %%
# Import modules

import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.io as pio
import os

# %%
# Getting the dataset to analyze

GTEx_file = "GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_median_tpm.gct"

# %%
# Converting to DataFrame

df = pd.read_csv(GTEx_file, sep='\t', skiprows=2)
df
# Out:
#                     Name  Description  Adipose - Subcutaneous  \
# 0      ENSG00000223972.5      DDX11L1                0.000000
# 1      ENSG00000227232.5       WASH7P                4.064030
# 2      ENSG00000278267.1    MIR6859-1                0.000000
# 3      ENSG00000243485.5  MIR1302-2HG                0.000000
# 4      ENSG00000237613.2      FAM138A                0.000000
# ...                  ...          ...                     ...
# 56195  ENSG00000198695.2       MT-ND6             3517.220000
# 56196  ENSG00000210194.1        MT-TE               11.903800
# 56197  ENSG00000198727.2       MT-CYB            23839.100000
# 56198  ENSG00000210195.2        MT-TT                0.616205
# 56199  ENSG00000210196.2        MT-TP                1.429970
#
#        Adipose - Visceral (Omentum)  Adrenal Gland  Artery - Aorta  \
# 0                          0.000000        0.00000         0.00000
# 1                          3.371110        2.68549         4.04762
# 2                          0.000000        0.00000         0.00000
# 3                          0.000000        0.00000         0.00000
# 4                          0.000000        0.00000         0.00000
# ...                             ...            ...             ...
# 56195                   3598.090000     6637.79000      6374.49000
# 56196                     11.203400       24.41390        22.65940
# 56197                  25511.700000    28799.40000     12919.40000
# 56198                      0.697191        1.50928         0.00000
# 56199                      1.192550        1.78041         1.57309
#
#        Artery - Coronary  Artery - Tibial      Bladder  Brain - Amygdala  ...  \
# 0                0.00000         0.000000      0.00000           0.00000  ...
# 1                3.90076         3.639630      5.16375           1.43859  ...
# 2                0.00000         0.000000      0.00000           0.00000  ...
# 3                0.00000         0.000000      0.00000           0.00000  ...
# 4                0.00000         0.000000      0.00000           0.00000  ...
# ...                  ...              ...          ...               ...  ...
# 56195         4972.73000      4635.000000   8275.20000        9631.77000  ...
# 56196           20.58800        18.257600     27.50560          40.58860  ...
# 56197        15943.20000     13051.500000  23663.20000       32931.80000  ...
# 56198            0.00000         0.544659      0.00000           3.44476  ...
# 56199            1.63648         1.950040      1.47692           5.67736  ...
#
#        Skin - Not Sun Exposed (Suprapubic)  Skin - Sun Exposed (Lower leg)  \
# 0                                 0.000000                         0.00000
# 1                                 5.932980                         6.13265
# 2                                 0.000000                         0.00000
# 3                                 0.000000                         0.00000
# 4                                 0.000000                         0.00000
# ...                                    ...                             ...
# 56195                          8919.460000                      8113.22000
# 56196                            32.932100                        31.33400
# 56197                         19058.200000                     17223.10000
# 56198                             0.884701                         1.11364
# 56199                             2.226800                         1.88828
#
#        Small Intestine - Terminal Ileum        Spleen       Stomach  \
# 0                              0.000000      0.000000      0.000000
# 1                              4.193780      5.926310      3.062480
# 2                              0.000000      0.000000      0.000000
# 3                              0.000000      0.000000      0.000000
# 4                              0.000000      0.000000      0.000000
# ...                                 ...           ...           ...
# 56195                       9764.490000   5477.360000   9628.750000
# 56196                         35.456000     24.934900     33.496300
# 56197                      24521.300000  11578.600000  27193.100000
# 56198                          0.815455      0.783492      0.803858
# 56199                          1.768040      0.948262      2.082370
#
#              Testis       Thyroid        Uterus        Vagina  Whole Blood
# 0          0.166403      0.000000      0.000000      0.000000      0.00000
# 1          4.702530      6.272550      7.190010      5.745540      2.64743
# 2          0.000000      0.000000      0.000000      0.000000      0.00000
# 3          0.054223      0.000000      0.000000      0.000000      0.00000
# 4          0.000000      0.000000      0.000000      0.000000      0.00000
# ...             ...           ...           ...           ...          ...
# 56195   1676.590000   2520.410000   3644.000000   2237.430000    960.29100
# 56196      2.871770      5.795670     10.370100      5.724510      3.49736
# 56197  15337.800000  19868.500000  15025.000000  12803.400000   2305.49000
# 56198      0.443781      0.000000      0.000000      0.000000      0.00000
# 56199      1.057760      0.982817      0.808096      0.737385      0.00000
#
# [56200 rows x 56 columns]

# %%
# Deleting the mitochondrial genes from the dataset

df['Description'] = df['Description'].astype(str)
df_without_mt = df[~df['Description'].str.startswith('MT-')]
df_without_mt
# Out:
#                            Name  Description  Adipose - Subcutaneous  \
# 0             ENSG00000223972.5      DDX11L1                 0.00000
# 1             ENSG00000227232.5       WASH7P                 4.06403
# 2             ENSG00000278267.1    MIR6859-1                 0.00000
# 3             ENSG00000243485.5  MIR1302-2HG                 0.00000
# 4             ENSG00000237613.2      FAM138A                 0.00000
# ...                         ...          ...                     ...
# 56158   ENSG00000223484.7_PAR_Y       TRPC6P                 0.00000
# 56159  ENSG00000124334.17_PAR_Y         IL9R                 0.00000
# 56160  ENSG00000185203.12_PAR_Y       WASIR1                 0.00000
# 56161  ENSG00000182484.15_PAR_Y       WASH6P                 0.00000
# 56162   ENSG00000227159.8_PAR_Y     DDX11L16                 0.00000
#
#        Adipose - Visceral (Omentum)  Adrenal Gland  Artery - Aorta  \
# 0                           0.00000        0.00000         0.00000
# 1                           3.37111        2.68549         4.04762
# 2                           0.00000        0.00000         0.00000
# 3                           0.00000        0.00000         0.00000
# 4                           0.00000        0.00000         0.00000
# ...                             ...            ...             ...
# 56158                       0.00000        0.00000         0.00000
# 56159                       0.00000        0.00000         0.00000
# 56160                       0.00000        0.00000         0.00000
# 56161                       0.00000        0.00000         0.00000
# 56162                       0.00000        0.00000         0.00000
#
#        Artery - Coronary  Artery - Tibial  Bladder  Brain - Amygdala  ...  \
# 0                0.00000          0.00000  0.00000           0.00000  ...
# 1                3.90076          3.63963  5.16375           1.43859  ...
# 2                0.00000          0.00000  0.00000           0.00000  ...
# 3                0.00000          0.00000  0.00000           0.00000  ...
# 4                0.00000          0.00000  0.00000           0.00000  ...
# ...                  ...              ...      ...               ...  ...
# 56158            0.00000          0.00000  0.00000           0.00000  ...
# 56159            0.00000          0.00000  0.00000           0.00000  ...
# 56160            0.00000          0.00000  0.00000           0.00000  ...
# 56161            0.00000          0.00000  0.00000           0.00000  ...
# 56162            0.00000          0.00000  0.00000           0.00000  ...
#
#        Skin - Not Sun Exposed (Suprapubic)  Skin - Sun Exposed (Lower leg)  \
# 0                                  0.00000                         0.00000
# 1                                  5.93298                         6.13265
# 2                                  0.00000                         0.00000
# 3                                  0.00000                         0.00000
# 4                                  0.00000                         0.00000
# ...                                    ...                             ...
# 56158                              0.00000                         0.00000
# 56159                              0.00000                         0.00000
# 56160                              0.00000                         0.00000
# 56161                              0.00000                         0.00000
# 56162                              0.00000                         0.00000
#
#        Small Intestine - Terminal Ileum   Spleen  Stomach    Testis  Thyroid  \
# 0                               0.00000  0.00000  0.00000  0.166403  0.00000
# 1                               4.19378  5.92631  3.06248  4.702530  6.27255
# 2                               0.00000  0.00000  0.00000  0.000000  0.00000
# 3                               0.00000  0.00000  0.00000  0.054223  0.00000
# 4                               0.00000  0.00000  0.00000  0.000000  0.00000
# ...                                 ...      ...      ...       ...      ...
# 56158                           0.00000  0.00000  0.00000  0.000000  0.00000
# 56159                           0.00000  0.00000  0.00000  0.000000  0.00000
# 56160                           0.00000  0.00000  0.00000  0.000000  0.00000
# 56161                           0.00000  0.00000  0.00000  0.000000  0.00000
# 56162                           0.00000  0.00000  0.00000  0.000000  0.00000
#
#         Uterus   Vagina  Whole Blood
# 0      0.00000  0.00000      0.00000
# 1      7.19001  5.74554      2.64743
# 2      0.00000  0.00000      0.00000
# 3      0.00000  0.00000      0.00000
# 4      0.00000  0.00000      0.00000
# ...        ...      ...          ...
# 56158  0.00000  0.00000      0.00000
# 56159  0.00000  0.00000      0.00000
# 56160  0.00000  0.00000      0.00000
# 56161  0.00000  0.00000      0.00000
# 56162  0.00000  0.00000      0.00000
#
# [56163 rows x 56 columns]

# %%
#Delete all genes that are considered ribo 

delete_genes = ["FAU", "MRPL13", "RPL10", "RPL10A", "RPL10L", "RPL11", "RPL12", "RPL13", "RPL13A", "RPL14",
    "RPL15", "RPL17", "RPL18", "RPL18A", "RPL19", "RPL21", "RPL22", "RPL22L1", "RPL23", "RPL23A",
    "RPL24", "RPL26", "RPL26L1", "RPL27", "RPL27A", "RPL28", "RPL29", "RPL3", "RPL30", "RPL31",
    "RPL32", "RPL34", "RPL35", "RPL35A", "RPL36", "RPL36A", "RPL36AL", "RPL37", "RPL37A", "RPL38",
    "RPL39", "RPL3L", "RPL4", "RPL41", "RPL5", "RPL6", "RPL7", "RPL7A", "RPL8", "RPL9", "RPLP0",
    "RPLP1", "RPLP2", "RPS10", "RPS11", "RPS12", "RPS13", "RPS15", "RPS15A", "RPS16", "RPS17",
    "RPS18", "RPS19", "RPS2", "RPS20", "RPS21", "RPS23", "RPS24", "RPS25", "RPS26", "RPS27",
    "RPS27A", "RPS27L", "RPS28", "RPS29", "RPS3", "RPS3A", "RPS4X", "RPS4Y1", "RPS5", "RPS6",
    "RPS7", "RPS8", "RPS9", "RPSA", "RSL24D1", "RSL24D1P11", "UBA52"]

df_no_mt_ribo = df_without_mt[~df_without_mt.iloc[:, 1].isin(delete_genes)]
df_no_mt_ribo
# Out:
#                            Name  Description  Adipose - Subcutaneous  \
# 0             ENSG00000223972.5      DDX11L1                 0.00000
# 1             ENSG00000227232.5       WASH7P                 4.06403
# 2             ENSG00000278267.1    MIR6859-1                 0.00000
# 3             ENSG00000243485.5  MIR1302-2HG                 0.00000
# 4             ENSG00000237613.2      FAM138A                 0.00000
# ...                         ...          ...                     ...
# 56158   ENSG00000223484.7_PAR_Y       TRPC6P                 0.00000
# 56159  ENSG00000124334.17_PAR_Y         IL9R                 0.00000
# 56160  ENSG00000185203.12_PAR_Y       WASIR1                 0.00000
# 56161  ENSG00000182484.15_PAR_Y       WASH6P                 0.00000
# 56162   ENSG00000227159.8_PAR_Y     DDX11L16                 0.00000
#
#        Adipose - Visceral (Omentum)  Adrenal Gland  Artery - Aorta  \
# 0                           0.00000        0.00000         0.00000
# 1                           3.37111        2.68549         4.04762
# 2                           0.00000        0.00000         0.00000
# 3                           0.00000        0.00000         0.00000
# 4                           0.00000        0.00000         0.00000
# ...                             ...            ...             ...
# 56158                       0.00000        0.00000         0.00000
# 56159                       0.00000        0.00000         0.00000
# 56160                       0.00000        0.00000         0.00000
# 56161                       0.00000        0.00000         0.00000
# 56162                       0.00000        0.00000         0.00000
#
#        Artery - Coronary  Artery - Tibial  Bladder  Brain - Amygdala  ...  \
# 0                0.00000          0.00000  0.00000           0.00000  ...
# 1                3.90076          3.63963  5.16375           1.43859  ...
# 2                0.00000          0.00000  0.00000           0.00000  ...
# 3                0.00000          0.00000  0.00000           0.00000  ...
# 4                0.00000          0.00000  0.00000           0.00000  ...
# ...                  ...              ...      ...               ...  ...
# 56158            0.00000          0.00000  0.00000           0.00000  ...
# 56159            0.00000          0.00000  0.00000           0.00000  ...
# 56160            0.00000          0.00000  0.00000           0.00000  ...
# 56161            0.00000          0.00000  0.00000           0.00000  ...
# 56162            0.00000          0.00000  0.00000           0.00000  ...
#
#        Skin - Not Sun Exposed (Suprapubic)  Skin - Sun Exposed (Lower leg)  \
# 0                                  0.00000                         0.00000
# 1                                  5.93298                         6.13265
# 2                                  0.00000                         0.00000
# 3                                  0.00000                         0.00000
# 4                                  0.00000                         0.00000
# ...                                    ...                             ...
# 56158                              0.00000                         0.00000
# 56159                              0.00000                         0.00000
# 56160                              0.00000                         0.00000
# 56161                              0.00000                         0.00000
# 56162                              0.00000                         0.00000
#
#        Small Intestine - Terminal Ileum   Spleen  Stomach    Testis  Thyroid  \
# 0                               0.00000  0.00000  0.00000  0.166403  0.00000
# 1                               4.19378  5.92631  3.06248  4.702530  6.27255
# 2                               0.00000  0.00000  0.00000  0.000000  0.00000
# 3                               0.00000  0.00000  0.00000  0.054223  0.00000
# 4                               0.00000  0.00000  0.00000  0.000000  0.00000
# ...                                 ...      ...      ...       ...      ...
# 56158                           0.00000  0.00000  0.00000  0.000000  0.00000
# 56159                           0.00000  0.00000  0.00000  0.000000  0.00000
# 56160                           0.00000  0.00000  0.00000  0.000000  0.00000
# 56161                           0.00000  0.00000  0.00000  0.000000  0.00000
# 56162                           0.00000  0.00000  0.00000  0.000000  0.00000
#
#         Uterus   Vagina  Whole Blood
# 0      0.00000  0.00000      0.00000
# 1      7.19001  5.74554      2.64743
# 2      0.00000  0.00000      0.00000
# 3      0.00000  0.00000      0.00000
# 4      0.00000  0.00000      0.00000
# ...        ...      ...          ...
# 56158  0.00000  0.00000      0.00000
# 56159  0.00000  0.00000      0.00000
# 56160  0.00000  0.00000      0.00000
# 56161  0.00000  0.00000      0.00000
# 56162  0.00000  0.00000      0.00000
#
# [56075 rows x 56 columns]

# %%
# Checking if the change worked - expecting *not* to find the gene

gene_name = "RPL22"
is_in_description = gene_name in df_no_mt_ribo.iloc[:, 1].values
is_in_description

# Indeed got "False"
# Out:
# False

# %%
# Organizing the dataframe to the wanted index

df_no_mt_ribo.set_index("Description", inplace=True)
df_no_mt_ribo
# Out:
#                                  Name  Adipose - Subcutaneous  \
# Description
# DDX11L1             ENSG00000223972.5                 0.00000
# WASH7P              ENSG00000227232.5                 4.06403
# MIR6859-1           ENSG00000278267.1                 0.00000
# MIR1302-2HG         ENSG00000243485.5                 0.00000
# FAM138A             ENSG00000237613.2                 0.00000
# ...                               ...                     ...
# TRPC6P        ENSG00000223484.7_PAR_Y                 0.00000
# IL9R         ENSG00000124334.17_PAR_Y                 0.00000
# WASIR1       ENSG00000185203.12_PAR_Y                 0.00000
# WASH6P       ENSG00000182484.15_PAR_Y                 0.00000
# DDX11L16      ENSG00000227159.8_PAR_Y                 0.00000
#
#              Adipose - Visceral (Omentum)  Adrenal Gland  Artery - Aorta  \
# Description
# DDX11L1                           0.00000        0.00000         0.00000
# WASH7P                            3.37111        2.68549         4.04762
# MIR6859-1                         0.00000        0.00000         0.00000
# MIR1302-2HG                       0.00000        0.00000         0.00000
# FAM138A                           0.00000        0.00000         0.00000
# ...                                   ...            ...             ...
# TRPC6P                            0.00000        0.00000         0.00000
# IL9R                              0.00000        0.00000         0.00000
# WASIR1                            0.00000        0.00000         0.00000
# WASH6P                            0.00000        0.00000         0.00000
# DDX11L16                          0.00000        0.00000         0.00000
#
#              Artery - Coronary  Artery - Tibial  Bladder  Brain - Amygdala  \
# Description
# DDX11L1                0.00000          0.00000  0.00000           0.00000
# WASH7P                 3.90076          3.63963  5.16375           1.43859
# MIR6859-1              0.00000          0.00000  0.00000           0.00000
# MIR1302-2HG            0.00000          0.00000  0.00000           0.00000
# FAM138A                0.00000          0.00000  0.00000           0.00000
# ...                        ...              ...      ...               ...
# TRPC6P                 0.00000          0.00000  0.00000           0.00000
# IL9R                   0.00000          0.00000  0.00000           0.00000
# WASIR1                 0.00000          0.00000  0.00000           0.00000
# WASH6P                 0.00000          0.00000  0.00000           0.00000
# DDX11L16               0.00000          0.00000  0.00000           0.00000
#
#              Brain - Anterior cingulate cortex (BA24)  ...  \
# Description                                            ...
# DDX11L1                                       0.00000  ...
# WASH7P                                        1.69285  ...
# MIR6859-1                                     0.00000  ...
# MIR1302-2HG                                   0.00000  ...
# FAM138A                                       0.00000  ...
# ...                                               ...  ...
# TRPC6P                                        0.00000  ...
# IL9R                                          0.00000  ...
# WASIR1                                        0.00000  ...
# WASH6P                                        0.00000  ...
# DDX11L16                                      0.00000  ...
#
#              Skin - Not Sun Exposed (Suprapubic)  \
# Description
# DDX11L1                                  0.00000
# WASH7P                                   5.93298
# MIR6859-1                                0.00000
# MIR1302-2HG                              0.00000
# FAM138A                                  0.00000
# ...                                          ...
# TRPC6P                                   0.00000
# IL9R                                     0.00000
# WASIR1                                   0.00000
# WASH6P                                   0.00000
# DDX11L16                                 0.00000
#
#              Skin - Sun Exposed (Lower leg)  Small Intestine - Terminal Ileum  \
# Description
# DDX11L1                             0.00000                           0.00000
# WASH7P                              6.13265                           4.19378
# MIR6859-1                           0.00000                           0.00000
# MIR1302-2HG                         0.00000                           0.00000
# FAM138A                             0.00000                           0.00000
# ...                                     ...                               ...
# TRPC6P                              0.00000                           0.00000
# IL9R                                0.00000                           0.00000
# WASIR1                              0.00000                           0.00000
# WASH6P                              0.00000                           0.00000
# DDX11L16                            0.00000                           0.00000
#
#               Spleen  Stomach    Testis  Thyroid   Uterus   Vagina  \
# Description
# DDX11L1      0.00000  0.00000  0.166403  0.00000  0.00000  0.00000
# WASH7P       5.92631  3.06248  4.702530  6.27255  7.19001  5.74554
# MIR6859-1    0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# MIR1302-2HG  0.00000  0.00000  0.054223  0.00000  0.00000  0.00000
# FAM138A      0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# ...              ...      ...       ...      ...      ...      ...
# TRPC6P       0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# IL9R         0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# WASIR1       0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# WASH6P       0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# DDX11L16     0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
#
#              Whole Blood
# Description
# DDX11L1          0.00000
# WASH7P           2.64743
# MIR6859-1        0.00000
# MIR1302-2HG      0.00000
# FAM138A          0.00000
# ...                  ...
# TRPC6P           0.00000
# IL9R             0.00000
# WASIR1           0.00000
# WASH6P           0.00000
# DDX11L16         0.00000
#
# [56075 rows x 55 columns]

# %%
# Dropping unnecessary coulombs

df_filtered = df_no_mt_ribo.drop("Name", axis = 1)
df_filtered
# Out:
#              Adipose - Subcutaneous  Adipose - Visceral (Omentum)  \
# Description
# DDX11L1                     0.00000                       0.00000
# WASH7P                      4.06403                       3.37111
# MIR6859-1                   0.00000                       0.00000
# MIR1302-2HG                 0.00000                       0.00000
# FAM138A                     0.00000                       0.00000
# ...                             ...                           ...
# TRPC6P                      0.00000                       0.00000
# IL9R                        0.00000                       0.00000
# WASIR1                      0.00000                       0.00000
# WASH6P                      0.00000                       0.00000
# DDX11L16                    0.00000                       0.00000
#
#              Adrenal Gland  Artery - Aorta  Artery - Coronary  \
# Description
# DDX11L1            0.00000         0.00000            0.00000
# WASH7P             2.68549         4.04762            3.90076
# MIR6859-1          0.00000         0.00000            0.00000
# MIR1302-2HG        0.00000         0.00000            0.00000
# FAM138A            0.00000         0.00000            0.00000
# ...                    ...             ...                ...
# TRPC6P             0.00000         0.00000            0.00000
# IL9R               0.00000         0.00000            0.00000
# WASIR1             0.00000         0.00000            0.00000
# WASH6P             0.00000         0.00000            0.00000
# DDX11L16           0.00000         0.00000            0.00000
#
#              Artery - Tibial  Bladder  Brain - Amygdala  \
# Description
# DDX11L1              0.00000  0.00000           0.00000
# WASH7P               3.63963  5.16375           1.43859
# MIR6859-1            0.00000  0.00000           0.00000
# MIR1302-2HG          0.00000  0.00000           0.00000
# FAM138A              0.00000  0.00000           0.00000
# ...                      ...      ...               ...
# TRPC6P               0.00000  0.00000           0.00000
# IL9R                 0.00000  0.00000           0.00000
# WASIR1               0.00000  0.00000           0.00000
# WASH6P               0.00000  0.00000           0.00000
# DDX11L16             0.00000  0.00000           0.00000
#
#              Brain - Anterior cingulate cortex (BA24)  \
# Description
# DDX11L1                                       0.00000
# WASH7P                                        1.69285
# MIR6859-1                                     0.00000
# MIR1302-2HG                                   0.00000
# FAM138A                                       0.00000
# ...                                               ...
# TRPC6P                                        0.00000
# IL9R                                          0.00000
# WASIR1                                        0.00000
# WASH6P                                        0.00000
# DDX11L16                                      0.00000
#
#              Brain - Caudate (basal ganglia)  ...  \
# Description                                   ...
# DDX11L1                             0.000000  ...
# WASH7P                              1.566050  ...
# MIR6859-1                           0.000000  ...
# MIR1302-2HG                         0.024264  ...
# FAM138A                             0.000000  ...
# ...                                      ...  ...
# TRPC6P                              0.000000  ...
# IL9R                                0.000000  ...
# WASIR1                              0.000000  ...
# WASH6P                              0.000000  ...
# DDX11L16                            0.000000  ...
#
#              Skin - Not Sun Exposed (Suprapubic)  \
# Description
# DDX11L1                                  0.00000
# WASH7P                                   5.93298
# MIR6859-1                                0.00000
# MIR1302-2HG                              0.00000
# FAM138A                                  0.00000
# ...                                          ...
# TRPC6P                                   0.00000
# IL9R                                     0.00000
# WASIR1                                   0.00000
# WASH6P                                   0.00000
# DDX11L16                                 0.00000
#
#              Skin - Sun Exposed (Lower leg)  Small Intestine - Terminal Ileum  \
# Description
# DDX11L1                             0.00000                           0.00000
# WASH7P                              6.13265                           4.19378
# MIR6859-1                           0.00000                           0.00000
# MIR1302-2HG                         0.00000                           0.00000
# FAM138A                             0.00000                           0.00000
# ...                                     ...                               ...
# TRPC6P                              0.00000                           0.00000
# IL9R                                0.00000                           0.00000
# WASIR1                              0.00000                           0.00000
# WASH6P                              0.00000                           0.00000
# DDX11L16                            0.00000                           0.00000
#
#               Spleen  Stomach    Testis  Thyroid   Uterus   Vagina  \
# Description
# DDX11L1      0.00000  0.00000  0.166403  0.00000  0.00000  0.00000
# WASH7P       5.92631  3.06248  4.702530  6.27255  7.19001  5.74554
# MIR6859-1    0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# MIR1302-2HG  0.00000  0.00000  0.054223  0.00000  0.00000  0.00000
# FAM138A      0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# ...              ...      ...       ...      ...      ...      ...
# TRPC6P       0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# IL9R         0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# WASIR1       0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# WASH6P       0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
# DDX11L16     0.00000  0.00000  0.000000  0.00000  0.00000  0.00000
#
#              Whole Blood
# Description
# DDX11L1          0.00000
# WASH7P           2.64743
# MIR6859-1        0.00000
# MIR1302-2HG      0.00000
# FAM138A          0.00000
# ...                  ...
# TRPC6P           0.00000
# IL9R             0.00000
# WASIR1           0.00000
# WASH6P           0.00000
# DDX11L16         0.00000
#
# [56075 rows x 54 columns]

# %%
# Making 3 sub-dataframes for each fat tissue.
# Each sub-dataframe doesn't have the other 2 fat tissues. 

df_only_adipose_subcutaneous = df_filtered.drop(['Adipose - Visceral (Omentum)', 'Breast - Mammary Tissue'], axis = 1)
df_only_adipose_visceral = df_filtered.drop(['Adipose - Subcutaneous', 'Breast - Mammary Tissue'], axis = 1)
df_only_breast = df_filtered.drop(["Adipose - Visceral (Omentum)", 'Adipose - Subcutaneous'], axis = 1)

# %%
# Creating a function to get marker genes for each sample in a dictionary

def get_marker_genes(df, FC_THRESH=2, MAX_EXP_THRESH=1e-4, PN=1e-9):

    df = df / df.sum(axis=0)
    marker_genes_dict = dict()

    # Loop through each tissue/sample
    for ii, sample in enumerate(df.columns):
        sample_expression = df[sample]
        other_samples_max_expression = df[df.columns[df.columns != sample]].max(axis=1)
        all_samples_max_exp = df.max(axis=1)

        # Calculate the ratio of expression in the current sample vs other samples
        tissue_ratio = (sample_expression[all_samples_max_exp > MAX_EXP_THRESH] + PN) / (other_samples_max_expression[all_samples_max_exp > MAX_EXP_THRESH] + PN)
        marker_genes_dict[sample] = tissue_ratio[tissue_ratio > FC_THRESH]

    return marker_genes_dict

get_marker_genes(df_filtered)
# Out:
# {'Adipose - Subcutaneous': Description
#  LEP    3.311776
#  dtype: float64,
#  'Adipose - Visceral (Omentum)': Description
#  ITLN1    6.112849
#  IL6      2.245161
#  MT1A     2.960495
#  dtype: float64,
#  'Adrenal Gland': Description
#  DHCR24      2.416061
#  MCOLN3      2.060277
#  HSD3B2    233.794937
#  SOAT1       6.311243
#  EPHX1       2.404092
#               ...
#  LONP1       2.706349
#  CTSA        2.226805
#  C2CD2       4.027418
#  RGN         2.156162
#  ZNF275      2.127335
#  Length: 69, dtype: float64,
#  'Artery - Aorta': Description
#  ITGA10      2.061956
#  FRZB        2.223676
#  IGFBP2      2.022894
#  LMCD1       2.264796
#  CYTL1       5.214830
#  MRAP2       2.555021
#  SMOC2       2.221285
#  ELN         2.426664
#  CRISPLD1    3.281175
#  ITGA8       2.057680
#  ANO1        2.397138
#  FBLN5       2.575412
#  CDH13       2.112110
#  MYH10       2.701660
#  dtype: float64,
#  'Artery - Coronary': Series([], dtype: float64),
#  'Artery - Tibial': Description
#  ID2        2.506518
#  RHOB       2.128685
#  FHL5       3.565790
#  HEY2       2.292372
#  TMEM181    4.391038
#  RERGL      3.636774
#  RASL12     2.041838
#  CRLF1      2.023371
#  COMP       4.594938
#  dtype: float64,
#  'Bladder': Description
#  RP11-343H5.4    2.970084
#  DHRS2           8.260713
#  dtype: float64,
#  'Brain - Amygdala': Series([], dtype: float64),
#  'Brain - Anterior cingulate cortex (BA24)': Series([], dtype: float64),
#  'Brain - Caudate (basal ganglia)': Series([], dtype: float64),
#  'Brain - Cerebellar Hemisphere': Series([], dtype: float64),
#  'Brain - Cerebellum': Description
#  GNG13     2.965583
#  SLC1A6    2.500058
#  dtype: float64,
#  'Brain - Cortex': Series([], dtype: float64),
#  'Brain - Frontal Cortex (BA9)': Series([], dtype: float64),
#  'Brain - Hippocampus': Description
#  CABP7    3.016155
#  dtype: float64,
#  'Brain - Hypothalamus': Description
#  DIRAS3      2.098315
#  CARTPT      3.727775
#  PMCH       26.661732
#  NGB         2.283360
#  HCRT       87.294618
#  OXT        69.922140
#  AVP       245.925173
#  dtype: float64,
#  'Brain - Nucleus accumbens (basal ganglia)': Description
#  GABRA5    2.372532
#  PDYN      3.839878
#  LAMP5     2.257468
#  dtype: float64,
#  'Brain - Putamen (basal ganglia)': Series([], dtype: float64),
#  'Brain - Spinal cord (cervical c-1)': Description
#  MARCKSL1     2.068153
#  HAPLN2       3.013622
#  CDK18        2.474985
#  TMEM206      2.793483
#  GJC2         2.952426
#                 ...
#  LINC00323    4.818927
#  S100B        2.035044
#  CHADL        2.758552
#  PRRG1        2.339169
#  PLP1         2.818939
#  Length: 67, dtype: float64,
#  'Brain - Substantia nigra': Description
#  SLC6A3    39.064637
#  TH         3.524858
#  dtype: float64,
#  'Breast - Mammary Tissue': Series([], dtype: float64),
#  'Cells - Cultured fibroblasts': Description
#  PLOD1     2.652881
#  TRNP1     2.305688
#  SEC22B    2.571956
#  FAP       3.062237
#  COL5A2    2.166981
#              ...
#  COL1A1    2.696770
#  CCBE1     2.862476
#  RCN3      2.782805
#  LGALS1    2.374336
#  KDELR3    4.664563
#  Length: 69, dtype: float64,
#  'Cells - EBV-transformed lymphocytes': Description
#  ISG15       6.267858
#  TNFRSF8    12.333238
#  RUNX3       3.019311
#  LCK         2.017731
#  PPIH        2.225732
#               ...
#  SH3KBP1     3.009559
#  PIM2        2.295277
#  PGK1        2.082084
#  P2RY10      8.242469
#  BTK         2.390944
#  Length: 182, dtype: float64,
#  'Cervix - Ectocervix': Series([], dtype: float64),
#  'Cervix - Endocervix': Description
#  SFRP4    2.000083
#  dtype: float64,
#  'Colon - Sigmoid': Description
#  UBXN10-AS1    3.157082
#  MAB21L2       2.543590
#  HAND2         2.359663
#  HAND1         3.654214
#  TACR2         2.377185
#  dtype: float64,
#  'Colon - Transverse': Description
#  SELENBP1     2.221156
#  LEFTY1       3.557527
#  SLC26A3      5.464991
#  CA1          3.787175
#  NXPE4       87.430881
#  CDX2         2.048436
#  C15orf48     3.179586
#  ZG16         3.251300
#  LGALS4       2.270677
#  CEACAM7      4.178929
#  ETHE1        2.536421
#  dtype: float64,
#  'Esophagus - Gastroesophageal Junction': Series([], dtype: float64),
#  'Esophagus - Mucosa': Description
#  PADI1        8.243338
#  CLCA4        6.907006
#  GBP6        11.266119
#  ECM1         3.923215
#  CRNN         4.161137
#                ...
#  TGM3        15.336601
#  PI3          3.394346
#  CYP4F29P     4.117465
#  RIPK4        2.321409
#  CSTB         3.485359
#  Length: 65, dtype: float64,
#  'Esophagus - Muscularis': Series([], dtype: float64),
#  'Fallopian Tube': Series([], dtype: float64),
#  'Heart - Atrial Appendage': Description
#  NPPA         637.693185
#  NPPB          48.633642
#  MYBPHL        31.407900
#  LINC01954      2.273008
#  BMP10        447.561820
#  PAM            2.377238
#  MYL7          14.079821
#  PRKAG2         2.105940
#  DKK3           2.031131
#  TBX5           3.405725
#  MYH6          10.940815
#  DHRS7C         2.110033
#  MYL4          67.543123
#  SBK2          28.387624
#  FAM155B        3.513800
#  dtype: float64,
#  'Heart - Left Ventricle': Description
#  HSPB7            2.192498
#  SMYD2            3.483779
#  MYL3             7.615909
#  CKMT2            2.193109
#  PKP2             2.022479
#  MYH7             2.002794
#  CTD-2201G16.1    2.834730
#  FHOD3            2.026632
#  TNNI3            2.587018
#  MYH7B            2.000314
#  dtype: float64,
#  'Kidney - Cortex': Description
#  PDZK1IP1      2.608208
#  FAM151A       2.500565
#  AK4           2.356547
#  PDZK1         2.191490
#  NPHS2         9.899685
#  REN           7.549112
#  ATP6V1B1      2.122516
#  NAT8          2.185035
#  UGT1A9        6.524432
#  PTH1R         5.280621
#  IL17RB        2.518895
#  AC009014.3    2.976247
#  SLC4A9        2.148550
#  LINC01187     3.586415
#  SLC34A1       2.307456
#  SLC17A1       3.789353
#  SLC17A3       5.378255
#  PODXL         2.617791
#  SLC5A12       6.525830
#  BBOX1         2.776927
#  SLC22A6       6.223677
#  SLC22A8       4.124309
#  SLC22A12      5.556847
#  ACY3          2.504042
#  SLC6A13       2.234097
#  RBP5          2.444709
#  TMEM52B       3.316373
#  SLC12A3       3.512164
#  SLC47A2       3.011412
#  LINC00671     3.744597
#  TMEM101       2.399371
#  SMIM24        2.478956
#  NPHS1         5.962964
#  SLC13A3       3.472568
#  GGT1          3.078629
#  TCN2          2.000079
#  MIOX          3.565931
#  CLDN2         2.136360
#  dtype: float64,
#  'Kidney - Medulla': Description
#  CLCNKA           5.527456
#  ITGB6            2.670195
#  EGF              2.455162
#  PP7080           2.560012
#  RP3-331H24.7     2.123017
#  FXYD4            4.050178
#  TMEM72           2.356451
#  PLAU             2.491747
#  SLC12A1         10.026797
#  UMOD             8.581887
#  WNK4             2.500894
#  SIM2             2.547611
#  DUSP9            2.958844
#  dtype: float64,
#  'Liver': Description
#  MASP2          8.200140
#  MST1P2         7.149312
#  NR0B2          2.697281
#  CYP4A11        3.534341
#  CYP4A22        4.843878
#                 ...
#  CYP2D7         8.405380
#  TTC38          2.053726
#  OTC            3.286475
#  SERPINA7     267.198949
#  F9          5331.394195
#  Length: 227, dtype: float64,
#  'Lung': Description
#  FCN3         12.199301
#  SFTPB        86.015353
#  MARCO         3.279987
#  VIPR1         4.099243
#  SLC34A2       4.221994
#  SLC39A8       2.123837
#  NKD2          3.478882
#  SCGB3A2      28.207852
#  SFTA2         6.393465
#  AGER          9.135987
#  INMT          2.132082
#  SFTPC       161.844381
#  TMEM2         2.021443
#  SFTA1P       15.268687
#  SFTPA2      308.515785
#  SFTPA1     3723.125072
#  SFTPD        23.684024
#  SCGB1A1      14.392436
#  ADAMTS8       3.590655
#  A2M           2.378801
#  GPRC5A        2.890249
#  ACVRL1        2.139025
#  RGCC          2.381159
#  CCL18         4.890197
#  TMEM100       5.306741
#  ACP5          2.257712
#  CYP2B7P       3.840388
#  NAPSA         3.977930
#  VEGFD         2.213855
#  dtype: float64,
#  'Minor Salivary Gland': Description
#  LTF          11.169681
#  STATH      1977.880893
#  ODAM         38.155151
#  FDCSP       510.338360
#  MUC7       8988.324291
#  CCL28        10.911443
#  SCGB3A1       2.624560
#  CRISP3       19.931465
#  C6orf58     828.268511
#  AZGP1         2.570020
#  PIP          64.817227
#  LCN2          2.392550
#  LRRC26        4.504236
#  MUC5B        29.046080
#  TCN1         43.963892
#  MMP3          2.463360
#  PRR4         58.818879
#  LYZ           7.863898
#  ZG16B       259.606475
#  KCNN4         2.367147
#  FUT2          3.406930
#  BPIFB2     1679.195400
#  SLPI         11.234211
#  dtype: float64,
#  'Muscle - Skeletal': Description
#  TCEA3             2.472448
#  TRIM63            4.261881
#  FHL3             10.737259
#  UTP11             2.514327
#  RP11-184I16.4    61.609934
#                     ...
#  CLTCL1            2.061693
#  MYO18B            2.181516
#  MAPK12            2.444418
#  PHKA1             2.391594
#  FHL1              2.463759
#  Length: 130, dtype: float64,
#  'Nerve - Tibial': Description
#  ANGPTL7        56.820451
#  NCMAP          11.994684
#  CLDN19          3.406222
#  SLC2A1          2.130460
#  FOXD3-AS1       5.555168
#  MPZ           128.537313
#  VIT             2.098835
#  AC093110.3      2.026582
#  EHBP1           2.002530
#  ITGA6           2.898819
#  APOD            4.800331
#  FGFBP2          7.081091
#  USP53           3.201563
#  GFRA3           3.999532
#  EGFL8           2.781088
#  COL28A1         3.375372
#  AHR             2.443005
#  ITGB8           4.545656
#  ARHGEF10        2.838837
#  ARHGAP19        2.322338
#  SFRP5           5.550267
#  SORCS1          3.068363
#  CNTF           13.310514
#  AP001350.4     11.102820
#  TMPRSS5         3.507369
#  PRIMA1          2.016987
#  PMP22           6.395747
#  NGFR            5.198701
#  ABCA8           2.039789
#  KIF19           5.075698
#  ST6GALNAC2      2.741290
#  AATK            2.013668
#  CDH19           3.264424
#  LGI4            3.814176
#  PRX            10.826993
#  MIA             3.312904
#  PLEKHA4         9.968850
#  DRP2            8.384254
#  dtype: float64,
#  'Ovary': Description
#  GSTM1             2.285335
#  GSTM5             2.381915
#  PROK1             3.820794
#  SPRR2F            5.053556
#  KLHDC8A           9.532297
#  GREB1             3.487772
#  OBSL1             2.250293
#  FOXL2             3.400707
#  FOXL2NB           3.097741
#  RBP1              3.988610
#  CLSTN2            3.830904
#  RASL11B           2.287861
#  MCC               2.829261
#  LRRC17            2.041279
#  VLDLR             2.460371
#  RP11-1100L3.8     2.136165
#  ACSM3             4.660876
#  WFIKKN2          58.111563
#  SIGLEC11          3.650155
#  SIGLEC16          3.305504
#  ZDHHC8P1          3.336945
#  ARX               6.475520
#  CHST7             2.680552
#  MUM1L1            6.767891
#  dtype: float64,
#  'Pancreas': Description
#  CTRC              3229.632038
#  CELA2A            1391.016343
#  CELA2B             493.981464
#  CELA3B            1069.547394
#  CELA3A            1048.598837
#  RN7SL186P       168367.363610
#  AMY2B                9.699856
#  AMY2A              630.718007
#  REG3G               14.331706
#  REG1B               34.056732
#  REG1A               13.636682
#  REG1CP            1008.217461
#  GCG                  2.705359
#  CPB1               135.526536
#  RP11-680B3.2       190.454236
#  SERPINI2            61.416657
#  SPINK1               9.157794
#  CLPS              4196.629882
#  BHLHA15              3.786801
#  CPA2                58.917332
#  CPA1              3718.888416
#  PRSS1             1531.677928
#  PRSS2              210.108959
#  PRSS3P1           2156.804519
#  PRSS3               28.120747
#  CEL                 73.190083
#  CELP                23.935337
#  PNLIP             5548.193769
#  PNLIPRP1          5709.147595
#  PNLIPRP2           181.353757
#  CUZD1              265.337462
#  RP11-326C3.2         2.222956
#  INS               2065.024000
#  ERP27                4.670057
#  PLA2G1B           1326.792083
#  SEL1L                2.103371
#  GP2                187.819185
#  AQP8                12.353417
#  CTRL                68.751690
#  CTRB2             3469.593355
#  CTRB1             4173.259726
#  RP11-331F4.4      3045.156832
#  SYCN               136.581597
#  KLK1                19.389570
#  RBPJL               62.788797
#  TPST2                2.264173
#  RP6-149D17.1       317.977552
#  dtype: float64,
#  'Pituitary': Description
#  TSHB              700.234273
#  TBX19               4.531160
#  POMC              764.541919
#  OTOS                2.594424
#  POU1F1            401.008375
#  PDCL3P4             2.057121
#  PRL             11459.661432
#  CGA              2332.745074
#  GHRHR             432.056546
#  NPTX2               2.845250
#  COL22A1            18.604454
#  LHX3              269.081464
#  FSHB              265.694743
#  CTD-2589M5.4       16.671302
#  GAL                12.140930
#  BAIAP3              2.663036
#  MYO15A              8.152943
#  GH1              8662.145199
#  MIR7-3HG           46.472665
#  TGFBR3L            23.604378
#  CHST8               3.169014
#  LHB               387.416291
#  ARHGAP36            2.947157
#  IGSF1               6.734862
#  dtype: float64,
#  'Prostate': Description
#  CREB3L4            2.354821
#  SLC45A3            4.092126
#  ANO7               3.777951
#  ACPP              40.766407
#  AMD1               2.160861
#  TRGJP             98.630369
#  STEAP2             3.947856
#  RP11-395B7.2       2.368908
#  NKX3-1             4.117727
#  MSMB             160.881690
#  FOXA1              2.018332
#  RDH11              2.065826
#  PRAC1             10.862179
#  HOXB13            17.889527
#  KLK3            1548.396335
#  KLK2             167.200840
#  KLK4              56.431612
#  dtype: float64,
#  'Skin - Not Sun Exposed (Suprapubic)': Series([], dtype: float64),
#  'Skin - Sun Exposed (Lower leg)': Description
#  LCE3D           2.390229
#  LCE2A           2.460532
#  LCE1D           2.269159
#  RP1-20N18.10    2.019556
#  SPRR2G          4.973085
#  KRT2            3.131754
#  DCD             2.264912
#  SCGB1B2P        2.482692
#  dtype: float64,
#  'Small Intestine - Terminal Ileum': Description
#  GUCA2A          3.939117
#  REG4            8.211724
#  REG3A           3.737311
#  RBP2           49.248952
#  SI             23.363668
#  FABP2           6.722624
#  SLC6A19         2.169071
#  FABP6           6.323545
#  CDHR2           3.506394
#  MEP1A           4.721961
#  MUC3A           2.610028
#  CLDN15          2.018028
#  DEFA6        5685.830736
#  DEFA5       15755.824952
#  SPINK4         15.576702
#  NLRP6           4.229893
#  MS4A8           5.749429
#  PLCB3           2.097278
#  NAALADL1        3.995266
#  APOA4           3.789269
#  OLFM4          13.730761
#  SLC10A2        21.995230
#  SLC51B          2.205505
#  TMIGD1          3.467070
#  CCL25          12.288448
#  dtype: float64,
#  'Spleen': Description
#  C1QA        3.707227
#  C1QC        3.895445
#  C1QB        3.535289
#  VCAM1       2.250599
#  FCRL2       3.173994
#                ...
#  IGLV1-47    2.217018
#  IGLV3-19    2.016658
#  IGLC7       2.019722
#  HMOX1       5.029428
#  GDPD2       3.345344
#  Length: 69, dtype: float64,
#  'Stomach': Description
#  AKR7A3          3.075301
#  CHIA           90.826630
#  MUC1            2.325914
#  MFSD4A          2.043292
#  SLC26A9         5.111029
#  CTSE            7.956016
#  GKN2            9.942141
#  GKN1          799.592299
#  GHRL           74.941622
#  CLDN18          4.236371
#  ANXA10          9.629068
#  CYSTM1          2.069155
#  DPCR1           9.822540
#  PGC           661.267256
#  TRIM50          4.090955
#  PSCA           12.146369
#  CA9            13.836650
#  LIPF         8496.391162
#  MUC6            6.956960
#  MUC5AC        678.875146
#  GIF          8807.359008
#  PGA3         6509.627220
#  PGA4        57274.304210
#  PGA5         3780.024126
#  VSIG2           5.031214
#  B4GALNT3        2.509960
#  RFLNA           3.199904
#  ATP4B        1858.061913
#  PDILT           3.300349
#  XYLT2           3.979669
#  ATP4A         128.742411
#  KCNE2          83.751338
#  CLIC6           6.370987
#  TFF2          234.769144
#  TFF1          100.024924
#  VSIG1           2.241997
#  dtype: float64,
#  'Testis': Description
#  TTLL10         12.153175
#  UBE2J2          2.241481
#  ACTRT2       4980.019788
#  ESPN            2.278937
#  CENPS           3.102233
#                 ...
#  SPANXB1       127.406574
#  SPANXN3    121060.922028
#  FMR1NB        969.918364
#  FATE1         349.007545
#  TKTL1          37.603205
#  Length: 559, dtype: float64,
#  'Thyroid': Description
#  TPO                64.412589
#  AC141930.3         19.362781
#  PAX8                2.742361
#  RP4-555D20.1        7.472225
#  RP4-555D20.2        4.554322
#  ZBED2               5.755074
#  ATP13A4             2.583329
#  PDE8B               3.056303
#  COL23A1             6.394366
#  VEGFA               2.553785
#  IYD                74.050637
#  SLC26A4-AS1         3.691656
#  SLC26A4            25.493117
#  SLC26A7            17.995815
#  PKHD1L1             3.944326
#  TRIB1               3.224111
#  TG               2170.512118
#  CTD-2182N23.1    3021.329465
#  CCL21               2.097209
#  FAM189A2            2.559758
#  FOXE1              22.102179
#  LCN12               3.614440
#  HHEX                2.613119
#  RP11-631N16.4       2.292097
#  RMST                3.349595
#  PTCSC3             19.070031
#  SFTA3               2.236392
#  NKX2-1              4.169487
#  TSHR              209.908867
#  SLC25A29            3.466715
#  DUOX2               4.227223
#  C16orf89            2.756437
#  LIPG                5.261279
#  EPOR                2.460609
#  ISM1                2.290260
#  RP4-568C11.4        3.159457
#  CTD-3184A7.4        2.084819
#  HIRA                3.037123
#  INPP5J              2.991617
#  dtype: float64,
#  'Uterus': Description
#  RERG     2.075706
#  RAP2C    4.735104
#  dtype: float64,
#  'Vagina': Description
#  SOX7    2.043611
#  EDN3    3.925415
#  dtype: float64,
#  'Whole Blood': Description
#  RP11-34P13.15     2.473041
#  RP11-34P13.16     2.125821
#  TNFRSF1B          2.168527
#  PADI4             4.556456
#  CDA               2.569435
#                     ...
#  NCF4              2.289534
#  APOBEC3A          3.195111
#  NFAM1             2.261178
#  ALAS2            49.204640
#  MPP1              2.061912
#  Length: 106, dtype: float64}

# %%
# Applying the marker gene function to the 3 sub-dataframes

only_adipose_visceral = get_marker_genes(df_only_adipose_visceral)
only_adipose_subcutaneous = get_marker_genes(df_only_adipose_subcutaneous)
only_breast = get_marker_genes(df_only_breast)

# %%
#Making a list for each fat tissue, with gene_name and exp_value

vis = list(only_adipose_visceral.values())
sub = list(only_adipose_subcutaneous.values())
bre = list(only_breast.values())

# %%
# Converting to lists to have only gene names 

lst_vis = []
df_split_vis = pd.DataFrame(vis)
for gene in df_split_vis:
    lst_vis.append(gene)

lst_sub = []
df_split_sub = pd.DataFrame(sub)
for gene in df_split_sub:
    lst_sub.append(gene)

lst_bre = []
df_split_bre = pd.DataFrame(bre)
for gene in df_split_bre:
    lst_bre.append(gene)

# %%
#Combine visceral (vis) and subcutaneous(sub), and delete genes from breast(bre)

union_vis_sub = lst_sub + lst_vis         
union_vis_sub = list(set(union_vis_sub)) 
sorted_lst = sorted(union_vis_sub)
intersect_bre_union = list(set(union_vis_sub).intersection(set(lst_bre)))
vis_genes_not_in_intersection = [gene for gene in lst_vis if gene not in intersect_bre_union]
sub_genes_not_in_intersection = [gene for gene in lst_sub if gene not in intersect_bre_union]

# %%
# Saving the final vis and sub lists, that dont have breast

subdirectory = "C:/python/Fat_tissue_analysis"
if not os.path.exists(subdirectory):
    os.makedirs(subdirectory)
file_path_vis = os.path.join(subdirectory, "vis.csv")
df_vis = pd.DataFrame(vis_genes_not_in_intersection, columns=["Gene"])
df_vis.to_csv(file_path_vis, index=False)

file_path_sub = os.path.join(subdirectory, "sub.csv")
df_sub = pd.DataFrame(sub_genes_not_in_intersection, columns=["Gene"])
df_sub.to_csv(file_path_sub, index=False)
